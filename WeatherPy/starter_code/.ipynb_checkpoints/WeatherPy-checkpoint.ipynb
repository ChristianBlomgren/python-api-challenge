# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 565

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = 'http://api.openweathermap.org/data/2.5/weather'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'{url}?q={city}&appid={weather_api_key}&units=imperial'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response = requests.get(city_url)
        city_weather = response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yuzhno-kurilsk
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | utrik
# Processing Record 4 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 5 of Set 1 | thompson
# Processing Record 6 of Set 1 | geraldton
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | vila velha
# Processing Record 9 of Set 1 | bathsheba
# Processing Record 10 of Set 1 | yershov
# Processing Record 11 of Set 1 | port-aux-francais
# Processing Record 12 of Set 1 | pimentel
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | iskateley
# Processing Record 15 of Set 1 | bubaque
# Processing Record 16 of Set 1 | port mathurin
# Processing Record 17 of Set 1 | maintirano
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | ashland
# Processing Record 20 of Set 1 | wailua homesteads
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          536
# Lat           536
# Lng           536
# Max Temp      536
# Humidity      536
# Cloudiness    536
# Wind Speed    536
# Country       536
# Date          536
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  yuzhno-kurilsk  44.0306  145.8556     36.37        88         100
# 1         ushuaia -54.8000  -68.3000     33.46        64           0
# 2           utrik  11.2278  169.8474     80.71        79         100
# 3        thompson  55.7435  -97.8558     30.36        80          40
# 4       geraldton -28.7667  114.6000     79.21        61           0
#
#    Wind Speed Country        Date
# 0       14.05      RU  1712464837
# 1        3.44      AR  1712464659
# 2       18.84      MH  1712464837
# 3        2.30      CA  1712464838
# 4       12.66      AU  1712464838

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        yuzhno-kurilsk  44.0306  145.8556     36.37        88         100
# 1               ushuaia -54.8000  -68.3000     33.46        64           0
# 2                 utrik  11.2278  169.8474     80.71        79         100
# 3              thompson  55.7435  -97.8558     30.36        80          40
# 4             geraldton -28.7667  114.6000     79.21        61           0
#
#          Wind Speed Country        Date
# City_ID
# 0             14.05      RU  1712464837
# 1              3.44      AR  1712464659
# 2             18.84      MH  1712464837
# 3              2.30      CA  1712464838
# 4             12.66      AU  1712464838

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.figure(figsize=(12, 8))
plt.subplot(221)
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], color='blue', alpha=0.6)
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title('Latitude vs. Temperature')
plt.grid()
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.figure(figsize=(12, 8))
plt.subplot(222)
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], color='green', alpha=0.6)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Latitude vs. Humidity')
plt.grid()
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.figure(figsize=(12, 8))
plt.subplot(223)
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], color='gray', alpha=0.6)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Latitude vs. Cloudiness')
plt.grid()
plt.tight_layout()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.figure(figsize=(12, 8))
plt.subplot(224)
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], color='orange', alpha=0.6)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Latitude vs. Wind Speed')
plt.grid()
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def create_linear_regression_plot(x, y, xlabel, ylabel, title):
    # Perform linear regression
    slope, intercept, rvalue, pvalue, stderr = linregress(x, y)
    
    # Calculate the regression line
    regression_line = slope * x + intercept
    
    # Create the scatter plot
    plt.scatter(x, y, color='b', label='Data Points')
    
    # Plot the regression line
    plt.plot(x, regression_line, color='r', label=f'Regression Line (R-squared={rvalue**2:.2f})')
    
    # Add labels and title
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    
    # Show legend
    plt.legend()
    
    # Show the plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        yuzhno-kurilsk  44.0306  145.8556     36.37        88         100
# 2                 utrik  11.2278  169.8474     80.71        79         100
# 3              thompson  55.7435  -97.8558     30.36        80          40
# 5           yellowknife  62.4560 -114.3525     32.56        89          20
# 7             bathsheba  13.2167  -59.5167     81.21        78          20
#
#          Wind Speed Country        Date
# City_ID
# 0             14.05      RU  1712464837
# 2             18.84      MH  1712464837
# 3              2.30      CA  1712464838
# 5             10.36      CA  1712464838
# 7             13.80      BB  1712464839

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                  ushuaia -54.8000  -68.3000     33.46        64           0
# 4                geraldton -28.7667  114.6000     79.21        61           0
# 6               vila velha -20.3297  -40.2925     75.94        84          75
# 9        port-aux-francais -49.3500   70.2167     47.89        97         100
# 10                pimentel  -6.8367  -79.9342     71.89        78           0
#
#          Wind Speed Country        Date
# City_ID
# 1              3.44      AR  1712464659
# 4             12.66      AU  1712464838
# 6              4.00      BR  1712464835
# 9             37.16      TF  1712464839
# 10            14.97      PE  1712464839

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
nhlat = northern_hemi_df['Lat']
nhmxtemp = northern_hemi_df['Max Temp']
create_linear_regression_plot(nhlat, nhmxtemp, 'Latitude', 'Max Temp', 'Linear regression on Northern Hemisphere (Temperature)')

# %%
# Linear regression on Southern Hemisphere
shlat = southern_hemi_df['Lat']
shmxtemp = southern_hemi_df['Max Temp']
create_linear_regression_plot(shlat, shmxtemp, 'Latitude', 'Max Temp', 'Linear regression on Southern Hemisphere (Temperature)')

# %% [markdown]
# **Discussion about the linear relationship:** You can see that in this previous two graphs, there is a correlation between the data points and the regression line.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
nhlat = northern_hemi_df['Lat']
nhhumidity = northern_hemi_df['Humidity']
create_linear_regression_plot(nhlat, nhhumidity, 'Latitude', 'Humidity', 'Linear regression on Northern Hemisphere (Humidity)')

# %%
# Southern Hemisphere
shlat = southern_hemi_df['Lat']
shhumidity = southern_hemi_df['Humidity']
create_linear_regression_plot(shlat, shhumidity, 'Latitude', 'Humidity', 'Linear regression on Southern Hemisphere (Humidity)')

# %% [markdown]
# **Discussion about the linear relationship:** There is not much of a correlation for either graph here.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
nhlat = northern_hemi_df['Lat']
nhcloudiness = northern_hemi_df['Cloudiness']
create_linear_regression_plot(nhlat, nhcloudiness, 'Latitude', 'Cloudiness', 'Linear regression on Northern Hemisphere (Cloudiness)')

# %%
# Southern Hemisphere
shlat = southern_hemi_df['Lat']
shcloudiness = southern_hemi_df['Cloudiness']
create_linear_regression_plot(shlat, shcloudiness, 'Latitude', 'Cloudiness', 'Linear regression on Southern Hemisphere (Cloudiness)')

# %% [markdown]
# **Discussion about the linear relationship:** The previous graphs have a multitude of errors in the linear regression and there is no correlation whatsoever.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
nhlat = northern_hemi_df['Lat']
nhwind = northern_hemi_df['Wind Speed']
create_linear_regression_plot(nhlat, nhwind, 'Latitude', 'Wind Speed', 'Linear regression on Northern Hemisphere (Wind Speed)')

# %%
# Southern Hemisphere
shlat = southern_hemi_df['Lat']
shwind = southern_hemi_df['Wind Speed']
create_linear_regression_plot(shlat, shwind, 'Latitude', 'Wind Speed', 'Linear regression on Southern Hemisphere (Wind Speed)')

# %% [markdown]
# **Discussion about the linear relationship:** The first graph has quite a few errors, whereas the second graph shows somewhat of a loose correlation.
